# %% [markdown]
# ## Basic setup

# %%
import os
import tensorflow as tf
import numpy as np

SEED = 1234
tf.random.set_seed(SEED)

cwd = os.getcwd()
drive_path = os.path.join(cwd, 'drive')
my_drive_path = os.path.join(drive_path, 'My Drive')

project_path = os.path.join(my_drive_path, 'AN2DL-Project')
data_path = os.path.join(project_path, 'data')
train_path = os.path.join(data_path, 'training')
test_path = os.path.join(data_path, 'test')
logs_path = os.path.join(project_path, 'logs')

# %%
from google.colab import drive
drive.mount(drive_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Images and labels

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

apply_data_augmentation = True
validation_split = 0.175

if apply_data_augmentation:
    train_data_gen = ImageDataGenerator(rotation_range=10,
                                        width_shift_range=1.5,
                                        height_shift_range=1.5,
                                        zoom_range=0.2,
                                        horizontal_flip=True,
                                        fill_mode='constant',
                                        cval=0,
                                        rescale=1./255,
                                        validation_split=validation_split)
else:
    train_data_gen = ImageDataGenerator(rescale=1./255,
                                        validation_split=validation_split)

# %%
import pandas as pd
import json

labels_df = pd.read_json(os.path.join(data_path,'train_gt.json'), orient='index')
labels_df = pd.DataFrame([(x,str(y)) for x,y in zip(labels_df.index, labels_df[0])])
labels_df.rename(columns={0:'file',1:'class'}, inplace=True)
print(labels_df)
# Out:
#            file class
# 0     14985.jpg     0
# 1     13358.jpg     0
# 2     10210.jpg     0
# 3     18202.jpg     0
# 4     14962.jpg     0
# ...         ...   ...
# 5609  14383.jpg     2
# 5610  11787.jpg     2
# 5611  15770.jpg     2
# 5612  10934.jpg     2
# 5613  10519.jpg     2
#
# [5614 rows x 2 columns]

# %% [markdown]
# ## Dataset

# %%
img_h = 299
img_w = 299
bs = 8

train_gen = train_data_gen.flow_from_dataframe(dataframe=labels_df,
                                            target_size=(img_h,img_w),
                                            directory=train_path,
                                            x_col='file',
                                            y_col='class',
                                            batch_size=bs, 
                                            class_mode='categorical',
                                            shuffle=True,
                                            seed=SEED)
# Out:
# Found 5614 validated image filenames belonging to 3 classes.

# %%
num_channels = 3
num_classes = 3

train_dataset = tf.data.Dataset.from_generator(lambda: train_gen,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([None, img_h, img_w, num_channels],
                                               [None, num_classes]))
train_dataset = train_dataset.repeat()

print(train_dataset)
# Out:
# <RepeatDataset shapes: ((None, 299, 299, 3), (None, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## Model

# %%
basic_model = tf.keras.applications.InceptionResNetV2(pooling='avg',
                                                      weights='imagenet',
                                                      include_top=False, 
                                                      input_shape=(img_h, img_w, num_channels))

model = tf.keras.Sequential()
model.add(basic_model)
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(1500, activation='linear'))
model.add(tf.keras.layers.Dense(units=num_classes, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Functio (None, 1536)              54336736
# _________________________________________________________________
# dropout (Dropout)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1500)              2305500
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                
kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-377.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-378.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-379.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-380.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-381.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-382.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-382.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-383.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-384.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-385.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-386.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-387.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-388.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-389.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-390.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-391.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-391.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-392.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-393.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-394.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-395.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-396.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-397.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-398.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-399.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-400.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-400.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-401.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-402.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-403.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-404.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-405.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-406.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-407.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-408.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-409.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-409.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-410.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-411.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-412.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-413.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-414.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-415.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-416.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-417.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-418.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-418.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-419.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-420.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-421.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-422.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-423.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-424.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-425.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-426.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-427.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-427.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-428.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-429.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-430.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-431.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-432.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-433.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-434.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-435.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-436.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-436.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-437.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-438.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-439.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-440.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-441.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-442.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-443.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-444.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-445.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-445.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-446.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.layer_with_weights-447.beta
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Functio (None, 1536)              54336736
# =================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# _________________________________________________________________

# %% [markdown]
# # Training data

# %%
dataset_size = 5606

iterator = iter(train_dataset)

file_name = 'training_deep_new.csv'
output_path = os.path.join(data_path, file_name)

with open(output_path, 'w') as f:
  for i in range(encoding_size):
    f.write('C{},'.format(i+1))
  f.write('Class\n')

  batch_count = int(dataset_size/bs)
  progress_bins = 20
  progress_period = int(batch_count/progress_bins)

  for i in range(batch_count):
    imgs, targets = next(iterator)
    img_encoded = encoder.predict(imgs)

    curr_bs = imgs.shape[0]
    for j in range(curr_bs):
      curr_encoded = img_encoded[j]

      for k in range(encoding_size):
        f.write('{},'.format(curr_encoded[k]))
      
      curr_target = targets[j]
      curr_target = np.argmax(curr_target)
      f.write('{}\n'.format(curr_target))

    if i%progress_period == progress_period-1:
      print('Completed {:.1f}%'.format(i/progress_period/progress_bins*100))

print('Saved {}'.format(file_name))
# Out:
# Completed 4.9%
# Completed 9.9%
# Completed 14.9%
# Completed 19.9%
# Completed 24.9%
# Completed 29.9%
# Completed 34.9%
# Completed 39.9%
# Completed 44.9%
# Completed 49.9%
# Completed 54.9%
# Completed 59.9%
# Completed 64.9%
# Completed 69.9%
# Completed 74.9%
# Completed 79.9%
# Completed 84.9%
# Completed 89.9%
# Completed 94.9%
# Completed 99.9%
# Saved training_deep_new.csv

# %% [markdown]
# # Test data

# %%
from PIL import Image

image_filenames = next(os.walk(test_path))[2]

file_name = 'test_deep_new.csv'
output_path = os.path.join(data_path, file_name)

with open(output_path, 'w') as f:
  f.write('Id,')
  for i in range(encoding_size-1):
    f.write('C{},'.format(i+1))
  f.write('C{}\n'.format(encoding_size))

  progress_bins = 20
  progress_period = int(len(image_filenames)/progress_bins)
  
  for i,image_name in enumerate(image_filenames):
      img = Image.open(test_path + '/' + image_name).convert('RGB')
      img = img.resize((img_w, img_h))
      img_array = np.array(img)
      img_array = np.expand_dims(img_array, 0)
      img_array = img_array * 1./255
      img_encoded = encoder.predict(img_array, batch_size=1)[0]

      f.write('{},'.format(image_name))
      for i in img_encoded[:-1]:
        f.write('{},'.format(i))
      f.write('{}\n'.format(img_encoded[-1]))

      if i%progress_period == progress_period-1:
        print('Completed {:.1f}%'.format(i/progress_period/progress_bins*100))

  print('Saved {}'.format(file_name))
# Out:
# Saved test_deep_new.csv
